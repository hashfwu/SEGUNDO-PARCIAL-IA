# %%
import os
import numpy as np
from NeuralNetwork import TicTacToeNN

# %%
# script_dir = os.path.dirname(os.path.abspath(__file__))

# # Crear rutas absolutas para los archivos de datos
# input_file = os.path.join(script_dir, 'data/input_data.csv')
# output_file = os.path.join(script_dir, 'data/output_data.csv')

# %%
input_data = np.array(np.genfromtxt("data/input_data.csv", delimiter=','))
output_data = np.array(np.genfromtxt("data/output_data.csv", delimiter=',')) 
# Arquitectura similar al mod27, 27, 81, 81, 243, 243, 81, 81, 27, 27, 9,elo Sequential
layer_sizes = [9, 27, 81, 243, 81, 27, 9]  # Define las capas
model = TicTacToeNN(layer_sizes)

# %%
model.load()
# Out:
# Pesos y sesgos cargados correctamente.

# %%
# Entrenar el modelo
model.train(input_data, output_data, epochs=5000, learning_rate=0.00001, view_rate=1, view_graph=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Entrenar el modelo
# ----> 2 model.train(input_data, output_data, epochs=5000, learning_rate=0.00001, view_rate=1, view_graph=True)
#
# File ~/Documents/UMSA II-2024/DAT-245/1128/Segundo parcial/Pregunta 2.4/NeuralNetwork.py:67, in TicTacToeNN.train(self, input_data, output_data, epochs, learning_rate, view_rate, view_graph)
#      65     ax.legend()
#      66     display.clear_output(wait=True)
# ---> 67     display.display(plt.gcf())
#      68 else:
#      69     print(f"Epoch {epoch}/{epochs} - MSE: {mse}")
#
# File ~/miniconda3/envs/spt/lib/python3.12/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# ...
